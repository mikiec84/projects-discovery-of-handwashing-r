# %%
# This allows .... to be used as placeholder value in the sample code cells
.... <- NULL

# %% [markdown]
# # A temporary placeholder project

# %% [markdown]
# This is just a temporary placeholder project so that the DataCamp build process will kick in correctly for this project repository. When you are happy with the notebook narrative (`project_narrative.ipynb`) your DataCamp contact will overwrite this notebook with the contents of `project_narrative.ipynb` + a scaffold of cells required to complete the DataCamp project.
#
# So, feel free to edit this notebook, but *be aware that it will be overwritten*! :)

# %% [markdown]
# ## 1. This is a task title

# %% [markdown]
# This will render as a text cell in notebook in the final DataCamp project.

# %% [markdown]
# This will render in the instructions sidebar.
#
# <hr>
#
# * What is the answer to the ultimate question of Life, the Universe, and Everything?

# %% [markdown]
# This will be the hint text in the instructions sidebar.

# %%
# This is the sample code the student will see
# What is the answer to the ultimate question of Life, the Universe, and Everything?
answer <- ....

# %%
# This is the correct code cell, the student won't see this.
answer <- 42

# %%
library(testthat) 
library(IRkernel.testthat)
run_tests({
    test_that("Have you read the Hitchhiker's Guide to the Galaxy?", {
        expect_equal(answer, 42)
    })
})

# %% [markdown]
# ## 2. This is a task title

# %% [markdown]
# This will render as a text cell in notebook in the final DataCamp project.

# %% [markdown]
# This will render in the instructions sidebar.

# %% [markdown]
# This will be the hint text in the instructions sidebar.

# %%
# This is the sample code the student will see
# ... YOUR CODE HERE ...

# %%
# This is the correct code cell, the student won't see this.
answer <- 42

# %%
run_tests({
    test_that("Placeholder test", {
        expect_equal(TRUE, TRUE)
    })
})

# %% [markdown]
# ## 3. This is a task title

# %% [markdown]
# This will render as a text cell in notebook in the final DataCamp project.

# %% [markdown]
# This will render in the instructions sidebar.

# %% [markdown]
# This will be the hint text in the instructions sidebar.

# %%
# This is the sample code the student will see
# ... YOUR CODE HERE ...

# %%
# This is the correct code cell, the student won't see this.
answer <- 42

# %%
run_tests({
    test_that("Placeholder test", {
        expect_equal(TRUE, TRUE)
    })
})

# %% [markdown]
# ## 4. This is a task title

# %% [markdown]
# This will render as a text cell in notebook in the final DataCamp project.

# %% [markdown]
# This will render in the instructions sidebar.

# %% [markdown]
# This will be the hint text in the instructions sidebar.

# %%
# This is the sample code the student will see
# ... YOUR CODE HERE ...

# %%
# This is the correct code cell, the student won't see this.
answer <- 42

# %%
run_tests({
    test_that("Placeholder test", {
        expect_equal(TRUE, TRUE)
    })
})

# %% [markdown]
# ## 5. This is a task title

# %% [markdown]
# This will render as a text cell in notebook in the final DataCamp project.

# %% [markdown]
# This will render in the instructions sidebar.

# %% [markdown]
# This will be the hint text in the instructions sidebar.

# %%
# This is the sample code the student will see
# ... YOUR CODE HERE ...

# %%
# This is the correct code cell, the student won't see this.
answer <- 42

# %%
run_tests({
    test_that("Placeholder test", {
        expect_equal(TRUE, TRUE)
    })
})
